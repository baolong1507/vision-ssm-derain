# %% [markdown]
# # 01_phase1_baseline_unet
#
#
# **Goal:** Establish a strong, stable baseline (UNet) for fair comparison.
#
# **Pipeline:** Dataset → UNet → L1/Charbonnier → PSNR/SSIM evaluation (PSNR is main monitor).

# %%
# (Colab) Uncomment if needed:
# !pip -q install -r ../requirements.txt
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# === 0) Setup ===
import os, sys
from pathlib import Path

from google.colab import drive
drive.mount("/content/drive")

PROJECT_ROOT = Path().resolve().parents[0].parents[0]  # notebooks/ -> repo root
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       2 import os, sys
#       3 from pathlib import Path
# ----> 5 from google.colab import drive
#       6 drive.mount("/content/drive")
#       8 PROJECT_ROOT = Path().resolve().parents[0].parents[0]  # notebooks/ -> repo root
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Data configuration & sanity check

# %%
from omegaconf import OmegaConf
data_cfg = OmegaConf.load("../configs/data_config.yaml")
print(data_cfg)

# sanity check paths
from pathlib import Path
root = Path(data_cfg.data_root)
for d in data_cfg.datasets:
    p = root / d
    print(d, "->", p, "exists:", p.exists())
# Out:
# {'data_root': '/content/drive/MyDrive/derain_project/data', 'datasets': ['Rain200L', 'Rain200H', 'Rain1400', 'DID-Data'], 'subdirs': {'inp': 'input', 'gt': 'target', 'train': 'train', 'val': 'val', 'test': 'test', 'rain': 'rain'}, 'img_size': 256, 'crop_size': 256, 'num_workers': 8, 'pin_memory': True}
# Rain200L -> \content\drive\MyDrive\derain_project\data\Rain200L exists: False
# Rain200H -> \content\drive\MyDrive\derain_project\data\Rain200H exists: False
# Rain1400 -> \content\drive\MyDrive\derain_project\data\Rain1400 exists: False
# DID-Data -> \content\drive\MyDrive\derain_project\data\DID-Data exists: False

# %% [markdown]
# ## Train

# %%
# === 1) Train Phase 1 ===
# !python ../scripts/train_phase1.py --cfg ../configs/phase1.yaml --data ../configs/data_config.yaml

# %% [markdown]
# ## Notes / Discussion
# - Check outputs under `outputs/phase1/`.
# - Use best checkpoint (highest val/psnr) for later comparison.
